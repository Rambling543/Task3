# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
df = pd.read_csv("student_data.csv")
print("First 5 rows of the dataset:")
print(df.head())
# Out:
# First 5 rows of the dataset:
#    StudentID   Age  Gender  Marks       City  Attendance
# 0          1  18.0    Male   85.0  Hyderabad          90
# 1          2  19.0  Female   78.0  Bangalore          88
# 2          3  17.0    Male   92.0  Hyderabad          95
# 3          4   NaN  Female   67.0    Chennai          85
# 4          5  20.0    Male   56.0  Hyderabad          70

# %%
print("\nMissing Values:")
print(df.isnull().sum())
print("Columns:", df.columns)
df = df.fillna(df.mean(numeric_only=True))
# Out:
# Missing Values:
# StudentID     0
# Age           1
# Gender        0
# Marks         1
# City          0
# Attendance    0
# dtype: int64
# Columns: Index(['StudentID', 'Age', 'Gender', 'Marks', 'City', 'Attendance'], dtype='object')

# %%
X_simple = df[['Attendance']]
y = df['Marks']   
X_train, X_test, y_train, y_test = train_test_split(X_simple, y, test_size=0.2, random_state=0)
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
print("\nEvaluation Metrics:")
print("MAE:", mean_absolute_error(y_test, y_pred))
print("MSE:", mean_squared_error(y_test, y_pred))
print("R² Score:", r2_score(y_test, y_pred))
# Out:
# Evaluation Metrics:
# MAE: 5.695753178353769
# MSE: 43.30378206941272
# R² Score: 0.8308446012913566

# %%
plt.scatter(X_test, y_test, color='blue', label='Actual')
plt.plot(X_test, y_pred, color='red', linewidth=2, label='Regression Line')
plt.title('Simple Linear Regression')
plt.xlabel('Hours Studied')
plt.ylabel('Score')
plt.legend()
plt.grid(True)
plt.show()
